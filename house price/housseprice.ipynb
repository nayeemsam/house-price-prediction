# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn import linear_model
# Out:
# C:\Users\nayee\AppData\Local\Temp\ipykernel_14328\2376525410.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
df=pd.read_csv("houseprice.csv")
df
# Out:
#    area    price
# 0  2000   550000
# 1  3400   600000
# 2  5000   900000
# 3  2345   250000
# 4  6000  1000000
# 5  5430   950000
# 6  2350   300000
# 7  2550   260000

# %%
plt.xlabel("area")
plt.ylabel("price")
plt.scatter(df.area,df.price,color='red',marker='+')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
reg=linear_model.LinearRegression()

reg.fit(df[['area']],df.price)
# Out:
# LinearRegression()

# %%
reg.fit(df[['area']],df.price)
# Out:
# LinearRegression()

# %%
predarea=[[2300]]
pred=reg.predict(predarea)
print(pred)
# Out:
# [357372.26185619]
# C:\Users\nayee\AppData\Roaming\Python\Python310\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %% [markdown]
# linear regression  Y=MX+C
# m-slope
# x-value
# c-interceptor
# m* area+b

# %%
reg.coef_
# Out:
# array([182.76551805])

# %%
reg.intercept_
# Out:
# -62988.42965164292

# %% [markdown]
# coeff(slope)*AREA+intercept
#
# m*area+b
# mx+c

# %%
182.76551805*2300-62988.42965164292
# Out:
# 357372.2618633571
